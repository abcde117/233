# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import openpyxl

# %%
d1=pd.read_excel('https://sipri.org/sites/default/files/SIPRI-Milex-data-1949-2020_0.xlsx',engine='openpyxl',sheet_name='Constant (2019) USD',header=4,index_col=0)
d1.columns=d1.iloc[0]
d2=pd.read_excel('https://sipri.org/sites/default/files/SIPRI-Milex-data-1949-2020_0.xlsx',engine='openpyxl',sheet_name='Per capita',header=5,index_col=0)
d2.columns=d2.iloc[0]
d3=pd.read_excel('https://sipri.org/sites/default/files/SIPRI-Milex-data-1949-2020_0.xlsx',engine='openpyxl',sheet_name='Share of GDP',header=4,index_col=0)
d3.columns=d3.iloc[0]

# %%
us=pd.DataFrame((d1.loc['USA'].loc[1995:2020],d2.loc['USA'].loc[1995:2020],d3.loc['USA'].loc[1995:2020]),index=['total','per','gdp'])
rus=pd.DataFrame((d1.loc['Russia'].loc[1995:2020],d2.loc['Russia'].loc[1995:2020],d3.loc['Russia'].loc[1995:2020]),index=['total','per','gdp'])
ukr=pd.DataFrame((d1.loc['Ukraine'].loc[1995:2020],d2.loc['Ukraine'].loc[1995:2020],d3.loc['Ukraine'].loc[1995:2020]),index=['total','per','gdp'])
uk=pd.DataFrame((d1.loc['UK'].loc[1995:2020],d2.loc['UK'].loc[1995:2020],d3.loc['UK'].loc[1995:2020]),index=['total','per','gdp'])

# %%
fig,ax1=plt.subplots(figsize=(8,8))
ax1.plot()
ax1.set_ylabel('total')
g1=plt.plot(ukr.iloc[0],color='orange',label='Ukraine total')
g2=plt.plot(rus.iloc[0],color='red',label='Russia total')
g3=plt.plot(uk.iloc[0],color='pink',label='UK total')
g4=plt.plot(us.iloc[0],color='magenta',label='USA total')
plt.legend(loc='upper right')
ax2=ax1.twinx()
ax2.plot()
ax2.set_ylabel('per')
g1=plt.plot(ukr.iloc[1],color='blue',label='Ukraine per')
g2=plt.plot(rus.iloc[1],color='green',label='Russia per')
g3=plt.plot(uk.iloc[1],color='white',label='UK per')
g4=plt.plot(us.iloc[1],color='black',label='USA per')
plt.legend(loc='lower right')
print(us.T.loc[2010:2020])
print(rus.T.loc[2010:2020])
print(ukr.T.loc[2010:2020])
print(uk.T.loc[2010:2020])
# Out:
#                  total          per       gdp
# Country
# 2010     865268.024824  2388.277051  0.049226
# 2011     855022.313452  2414.398290  0.048402
# 2012     807530.267115  2309.247321  0.044774
# 2013     745415.975253  2146.737809  0.040467
# 2014     699563.841964  2032.767577  0.036959
# 2015     683677.745113  1975.295978  0.034778
# 2016     681579.835831  1980.881625  0.034189
# 2017     674557.211178  1989.490159  0.033134
# 2018     694859.577914  2086.515430  0.033162
# 2019     734344.100000  2231.608604  0.034271
# 2020     766582.825358  2351.135881  0.037412
#                 total         per       gdp
# Country
# 2010     49833.896789  409.259305  0.035851
# 2011     53184.608746  488.768577  0.034330
# 2012     61622.415898  565.783736  0.036892
# 2013     64625.507317  612.178190  0.038540
# 2014     69260.683437  585.467114  0.041130
# 2015     74649.044319  458.128738  0.048715
# 2016     80026.931315  476.648538  0.054251
# 2017     64847.527603  459.788303  0.042490
# 2018     62404.221344  422.750974  0.036925
# 2019     65201.335848  446.975565  0.038321
# 2020     66838.181926  422.878443  0.042634
#                total         per       gdp
# Country
# 2010     2238.557061   56.504266  0.019024
# 2011     2013.413567   54.851048  0.015336
# 2012     2275.623463   62.390934  0.016133
# 2013     2329.182704   63.925689  0.015793
# 2014     3199.796117   66.439538  0.022450
# 2015     3904.937391   65.883205  0.032512
# 2016     3990.151513   65.836803  0.031548
# 2017     3987.782334   72.981655  0.028844
# 2018     4744.195404   94.238861  0.031924
# 2019     5419.138048  123.180025  0.035225
# 2020     5995.031272  135.460592  0.041292
#                 total          per       gdp
# Country
# 2010     63177.175157  1008.183306  0.025782
# 2011     61041.313094  1039.793097  0.025027
# 2012     59346.290335  1014.369364  0.024206
# 2013     57176.620686   982.360429  0.022936
# 2014     56154.307309  1024.034659  0.021839
# 2015     53995.686799   910.872609  0.020455
# 2016     53807.407560   804.358694  0.019814
# 2017     53448.762750   773.797428  0.019463
# 2018     54162.945224   829.294559  0.019488
# 2019     56856.133066   841.936880  0.020130
# 2020     58484.918359   872.616722  0.022465

# %%
fig,ax1=plt.subplots(figsize=(8,8))
ax1.plot()
ax1.set_ylabel('total')
g1=plt.plot(ukr.iloc[0],color='orange',label='Ukraine total')
g2=plt.plot(rus.iloc[0],color='red',label='Russia total')
g3=plt.plot(uk.iloc[0],color='pink',label='UK total')
g4=plt.plot(us.iloc[0],color='magenta',label='USA total')
plt.legend(loc='upper right')
ax2=ax1.twinx()
ax2.plot()
ax2.set_ylabel('per')
g1=plt.plot(ukr.iloc[1],color='blue',label='Ukraine per')
g2=plt.plot(rus.iloc[1],color='green',label='Russia per')
g3=plt.plot(uk.iloc[1],color='white',label='UK per')
g4=plt.plot(us.iloc[1],color='black',label='USA per')
plt.legend(loc='lower right')
ax3=ax2.twinx()
ax3.plot()
ax3.set_ylabel('gdp')
g5=plt.plot(ukr.iloc[2],color='grey',label='Ukraine gdp')
g6=plt.plot(rus.iloc[2],color='black',label='Russia gdp')
g3=plt.plot(uk.iloc[2],color='cyan',label='UK gdp')
g4=plt.plot(us.iloc[2],color='purple',label='USA gdp')
plt.legend(loc='upper left')
print(us.T.loc[2010:2020])
print(rus.T.loc[2010:2020])
print(ukr.T.loc[2010:2020])
print(uk.T.loc[2010:2020])
# Out:
#                  total          per       gdp
# Country
# 2010     865268.024824  2388.277051  0.049226
# 2011     855022.313452  2414.398290  0.048402
# 2012     807530.267115  2309.247321  0.044774
# 2013     745415.975253  2146.737809  0.040467
# 2014     699563.841964  2032.767577  0.036959
# 2015     683677.745113  1975.295978  0.034778
# 2016     681579.835831  1980.881625  0.034189
# 2017     674557.211178  1989.490159  0.033134
# 2018     694859.577914  2086.515430  0.033162
# 2019     734344.100000  2231.608604  0.034271
# 2020     766582.825358  2351.135881  0.037412
#                 total         per       gdp
# Country
# 2010     49833.896789  409.259305  0.035851
# 2011     53184.608746  488.768577  0.034330
# 2012     61622.415898  565.783736  0.036892
# 2013     64625.507317  612.178190  0.038540
# 2014     69260.683437  585.467114  0.041130
# 2015     74649.044319  458.128738  0.048715
# 2016     80026.931315  476.648538  0.054251
# 2017     64847.527603  459.788303  0.042490
# 2018     62404.221344  422.750974  0.036925
# 2019     65201.335848  446.975565  0.038321
# 2020     66838.181926  422.878443  0.042634
#                total         per       gdp
# Country
# 2010     2238.557061   56.504266  0.019024
# 2011     2013.413567   54.851048  0.015336
# 2012     2275.623463   62.390934  0.016133
# 2013     2329.182704   63.925689  0.015793
# 2014     3199.796117   66.439538  0.022450
# 2015     3904.937391   65.883205  0.032512
# 2016     3990.151513   65.836803  0.031548
# 2017     3987.782334   72.981655  0.028844
# 2018     4744.195404   94.238861  0.031924
# 2019     5419.138048  123.180025  0.035225
# 2020     5995.031272  135.460592  0.041292
#                 total          per       gdp
# Country
# 2010     63177.175157  1008.183306  0.025782
# 2011     61041.313094  1039.793097  0.025027
# 2012     59346.290335  1014.369364  0.024206
# 2013     57176.620686   982.360429  0.022936
# 2014     56154.307309  1024.034659  0.021839
# 2015     53995.686799   910.872609  0.020455
# 2016     53807.407560   804.358694  0.019814
# 2017     53448.762750   773.797428  0.019463
# 2018     54162.945224   829.294559  0.019488
# 2019     56856.133066   841.936880  0.020130
# 2020     58484.918359   872.616722  0.022465

# %% [markdown]
# #関数化

# %%
def make(x):
  d=pd.DataFrame((d1.loc[x].loc[1995:2020],d2.loc[x].loc[1995:2020],d3.loc[x].loc[1995:2020]),index=['total','per','gdp'])
  return d

# %%
def pyp2(a,b,c,d):
   fig,ax1=plt.subplots(figsize=(10,10))
   ax1.plot()
   ax1.set_ylabel('total')
   g1=plt.plot(make(a).iloc[c],color='orange',label=a+','+'total')
   g2=plt.plot(make(b).iloc[c],color='red',label=b+','+'total')

   plt.legend(loc='upper right')
   ax2=ax1.twinx()
   ax2.plot()
   ax2.set_ylabel('per')
   g1=plt.plot(make(a).iloc[d],color='blue',label=a+','+'per')
   g2=plt.plot(make(b).iloc[d],color='green',label=b+','+'per')

   plt.legend(loc='lower right')
   plt.show()
   print(make(a).T.loc[2010:])
   print(make(b).T.loc[2010:])

# %%
pyp2('USA','Russia',0,2)
# Out:
#                  total          per       gdp
# Country
# 2010     865268.024824  2388.277051  0.049226
# 2011     855022.313452  2414.398290  0.048402
# 2012     807530.267115  2309.247321  0.044774
# 2013     745415.975253  2146.737809  0.040467
# 2014     699563.841964  2032.767577  0.036959
# 2015     683677.745113  1975.295978  0.034778
# 2016     681579.835831  1980.881625  0.034189
# 2017     674557.211178  1989.490159  0.033134
# 2018     694859.577914  2086.515430  0.033162
# 2019     734344.100000  2231.608604  0.034271
# 2020     766582.825358  2351.135881  0.037412
#                 total         per       gdp
# Country
# 2010     49833.896789  409.259305  0.035851
# 2011     53184.608746  488.768577  0.034330
# 2012     61622.415898  565.783736  0.036892
# 2013     64625.507317  612.178190  0.038540
# 2014     69260.683437  585.467114  0.041130
# 2015     74649.044319  458.128738  0.048715
# 2016     80026.931315  476.648538  0.054251
# 2017     64847.527603  459.788303  0.042490
# 2018     62404.221344  422.750974  0.036925
# 2019     65201.335848  446.975565  0.038321
# 2020     66838.181926  422.878443  0.042634

# %%
def uppyp2(x,y):
   fig,ax1=plt.subplots(figsize=(10,10))
   ax1.plot()
   ax1.set_ylabel('total')
   g1=plt.plot(make(x).iloc[0],color='orange',label=x+','+'total')
   g2=plt.plot(make(y).iloc[0],color='red',label=y+','+'total')
   plt.legend(loc='upper right')
   ax2=ax1.twinx()
   ax2.plot()
   ax2.set_ylabel('per')
   g1=plt.plot(make(x).iloc[1],color='blue',label=x+','+'per')
   g2=plt.plot(make(y).iloc[1],color='green',label=y+','+'per')
   plt.legend(loc='lower right')
   ax3=ax2.twinx()
   ax3.plot()
   ax3.set_ylabel('gdp')
   g5=plt.plot(make(x).iloc[2],color='grey',label=x+','+'gdp')
   g6=plt.plot(make(y).iloc[2],color='black',label=y+','+'gdp')
   plt.legend(loc='upper left')
   plt.show()
   print(make(x).T.loc[2010:])
   print(make(y).T.loc[2010:])

# %%
uppyp2('USA','Russia')
# Out:
#                  total          per       gdp
# Country
# 2010     865268.024824  2388.277051  0.049226
# 2011     855022.313452  2414.398290  0.048402
# 2012     807530.267115  2309.247321  0.044774
# 2013     745415.975253  2146.737809  0.040467
# 2014     699563.841964  2032.767577  0.036959
# 2015     683677.745113  1975.295978  0.034778
# 2016     681579.835831  1980.881625  0.034189
# 2017     674557.211178  1989.490159  0.033134
# 2018     694859.577914  2086.515430  0.033162
# 2019     734344.100000  2231.608604  0.034271
# 2020     766582.825358  2351.135881  0.037412
#                 total         per       gdp
# Country
# 2010     49833.896789  409.259305  0.035851
# 2011     53184.608746  488.768577  0.034330
# 2012     61622.415898  565.783736  0.036892
# 2013     64625.507317  612.178190  0.038540
# 2014     69260.683437  585.467114  0.041130
# 2015     74649.044319  458.128738  0.048715
# 2016     80026.931315  476.648538  0.054251
# 2017     64847.527603  459.788303  0.042490
# 2018     62404.221344  422.750974  0.036925
# 2019     65201.335848  446.975565  0.038321
# 2020     66838.181926  422.878443  0.042634

# %%
def suppyp2(x,y,z):
   fig,ax1=plt.subplots(figsize=(10,10))
   ax1.plot()
   ax1.set_ylabel('total')
   g1=plt.plot(make(x).iloc[0],color='orange',label=x+','+'total')
   g2=plt.plot(make(y).iloc[0],color='red',label=y+','+'total')
   g3=plt.plot(make(z).iloc[0],color='magenta',label=z+','+'total')
   plt.legend(loc='upper right')
   ax2=ax1.twinx()
   ax2.plot()
   ax2.set_ylabel('per')
   g1=plt.plot(make(x).iloc[1],color='blue',label=x+','+'per')
   g2=plt.plot(make(y).iloc[1],color='green',label=y+','+'per')
   g3=plt.plot(make(z).iloc[1],color='pink',label=z+','+'per')
   plt.legend(loc='lower right')
   ax3=ax2.twinx()
   ax3.plot()
   ax3.set_ylabel('gdp')
   g5=plt.plot(make(x).iloc[2],color='grey',label=x+','+'gdp')
   g6=plt.plot(make(y).iloc[2],color='black',label=y+','+'gdp')
   g3=plt.plot(make(z).iloc[2],color='cyan',label=z+','+'gdp')
   plt.legend(loc='upper left')
   plt.show()
   print(make(x).T.loc[2010:])
   print(make(y).T.loc[2010:])
   print(make(z).T.loc[2010:])

# %%
suppyp2('USA','Russia','Ukraine')
# Out:
#                  total          per       gdp
# Country
# 2010     865268.024824  2388.277051  0.049226
# 2011     855022.313452  2414.398290  0.048402
# 2012     807530.267115  2309.247321  0.044774
# 2013     745415.975253  2146.737809  0.040467
# 2014     699563.841964  2032.767577  0.036959
# 2015     683677.745113  1975.295978  0.034778
# 2016     681579.835831  1980.881625  0.034189
# 2017     674557.211178  1989.490159  0.033134
# 2018     694859.577914  2086.515430  0.033162
# 2019     734344.100000  2231.608604  0.034271
# 2020     766582.825358  2351.135881  0.037412
#                 total         per       gdp
# Country
# 2010     49833.896789  409.259305  0.035851
# 2011     53184.608746  488.768577  0.034330
# 2012     61622.415898  565.783736  0.036892
# 2013     64625.507317  612.178190  0.038540
# 2014     69260.683437  585.467114  0.041130
# 2015     74649.044319  458.128738  0.048715
# 2016     80026.931315  476.648538  0.054251
# 2017     64847.527603  459.788303  0.042490
# 2018     62404.221344  422.750974  0.036925
# 2019     65201.335848  446.975565  0.038321
# 2020     66838.181926  422.878443  0.042634
#                total         per       gdp
# Country
# 2010     2238.557061   56.504266  0.019024
# 2011     2013.413567   54.851048  0.015336
# 2012     2275.623463   62.390934  0.016133
# 2013     2329.182704   63.925689  0.015793
# 2014     3199.796117   66.439538  0.022450
# 2015     3904.937391   65.883205  0.032512
# 2016     3990.151513   65.836803  0.031548
# 2017     3987.782334   72.981655  0.028844
# 2018     4744.195404   94.238861  0.031924
# 2019     5419.138048  123.180025  0.035225
# 2020     5995.031272  135.460592  0.041292

# %%
us
# Out:
# Country           1995           1996           1997           1998  \
# total    496360.310689  469361.049768  466933.001712  456389.548821
# per        1115.737380    1073.138652    1078.958834    1057.493335
# gdp           0.038602       0.035550       0.034056       0.032016
#
# Country           1999           2000           2001           2002  \
# total    457512.650980  475217.437620  479076.987393  537911.929714
# per        1070.173661    1136.222661    1165.833778    1317.404780
# gdp           0.030857       0.031122       0.031238       0.034476
#
# Country           2003           2004  ...           2011           2012  \
# total    612232.611747  667284.639163  ...  855022.313452  807530.267115
# per        1520.042813    1686.305842  ...    2414.398290    2309.247321
# gdp           0.038272       0.040163  ...       0.048402       0.044774
#
# Country           2013           2014           2015           2016  \
# total    745415.975253  699563.841964  683677.745113  681579.835831
# per        2146.737809    2032.767577    1975.295978    1980.881625
# gdp           0.040467       0.036959       0.034778       0.034189
#
# Country           2017           2018           2019           2020
# total    674557.211178  694859.577914  734344.100000  766582.825358
# per        1989.490159    2086.515430    2231.608604    2351.135881
# gdp           0.033134       0.033162       0.034271       0.037412
#
# [3 rows x 26 columns]
